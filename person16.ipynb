# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/person16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch01/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
      #if result["distance"]<1.1:
       # path = os.path.join(path+str(file_name))
        #with open(path, 'rb') as rstream:
         #   container = rstream.read()
           
          #  path2 = os.path.join(dstPath+'/'+str(file_name))
           # with open(path2, 'wb') as wstream:
            #  wstream.write(container)
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.286431
# location: /content/newperson16/batch01/a.pngb'Wavy_Hair'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# location: /content/newperson16/batch01/a.pngb'Blond_Hair'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# location: /content/newperson16/batch01/a.pngb'Sideburns'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch02/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3833015
# location: /content/newperson16/batch02/a.pngb'Mouth_Slightly_Open'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3996979
# location: /content/newperson16/batch02/a.pngb'5_o_Clock_Shadow'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2240309
# location: /content/newperson16/batch02/a.pngb'Big_Lips'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4431301
# location: /content/newperson16/batch02/a.pngb'Eyeglasses'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch03/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4805783
# location: /content/newperson16/batch03/a.pngb'Bags_Under_Eyes'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1732473
# location: /content/newperson16/batch03/a.pngb'Attractive'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# location: /content/newperson16/batch03/a.pngb'5_o_Clock_Shadow'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4830761
# location: /content/newperson16/batch03/a.pngb'Eyeglasses'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3041153
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch04/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2186587
# location: /content/newperson16/batch04/a.pngb'Big_Lips'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4098517
# location: /content/newperson16/batch04/a.pngb'Wearing_Necklace'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# location: /content/newperson16/batch04/a.pngb'Rosy_Cheeks'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch05/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4067918
# location: /content/newperson16/batch05/a.pngb'Pale_Skin'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2535824
# location: /content/newperson16/batch05/a.pngb'Rosy_Cheeks'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4617693
# location: /content/newperson16/batch05/a.pngb'Bags_Under_Eyes'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3226774
# location: /content/newperson16/batch05/a.pngb'Brown_Hair'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch06/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3361112
# location: /content/newperson16/batch06/a.pngb'Sideburns'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2854675
# location: /content/newperson16/batch06/a.pngb'Arched_Eyebrows'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2421352
# location: /content/newperson16/batch06/a.pngb'Big_Lips'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch07/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4927744
# location: /content/newperson16/batch07/a.pngb'Bags_Under_Eyes'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# location: /content/newperson16/batch07/a.pngb'Attractive'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.268037
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson16/batch08/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000002.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3986647
# location: /content/newperson16/batch08/a.pngb'Narrow_Eyes'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3474221
# location: /content/newperson16/batch08/a.pngb'Goatee'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.368854
# location: /content/newperson16/batch08/a.pngb'Bangs'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1874936
# ...
