# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/person06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip install deepface
from deepface import DeepFace

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/facenet_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/root/.deepface/weights/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/person06.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('person06/')

# %%
import os
from PIL import Image

fileName = os.listdir('/content/person06/person06/batch8/')
width = 160
height = 160

for img in fileName:
  pic = Image.open('/content/person06/person06/batch8/'+img)
  newpic = pic.resize((width,height),Image.ANTIALIAS)
  print(newpic)
  newpic.save('/content/new06/batch8/'+img)

# %%
import imageio
import imageio.core.util
def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch1/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9385215
# /content/new06/batch1/a.pngb'Arched_Eyebrows'.png3.png
# verified: /content/new06/batch1/a.pngb'Arched_Eyebrows'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.5837017
# /content/new06/batch1/a.pngb'Bags_Under_Eyes'.png4.png
# verified: /content/new06/batch1/a.pngb'Bags_Under_Eyes'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.8812044
# /content/new06/batch1/a.pngb'Bags_Under_Eyes'.png3.png
# verified: /content/new06/batch1/a.pngb'Bags_Under_Eyes'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
from deepface import DeepFace

import imageio
import imageio.core.util
def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch2/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9393585
# /content/new06/batch2/a.pngb'Bangs'.png1.png
# verified: /content/new06/batch2/a.pngb'Bangs'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.78306895
# /content/new06/batch2/a.pngb'Big_Nose'.png2.png
# verified: /content/new06/batch2/a.pngb'Big_Nose'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.6817146
# /content/new06/batch2/a.pngb'Black_Hair'.png6.png
# verified: /content/new06/batch2/a.pngb'Black_Hair'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.95406514
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch3/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.86823714
# /content/new06/batch3/a.pngb'Bushy_Eyebrows'.png7.png
# verified: /content/new06/batch3/a.pngb'Bushy_Eyebrows'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9813559
# /content/new06/batch3/a.pngb'Bushy_Eyebrows'.png8.png
# verified: /content/new06/batch3/a.pngb'Bushy_Eyebrows'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.89614266
# /content/new06/batch3/a.pngb'Brown_Hair'.png2.png
# verified: /content/new06/batch3/a.pngb'Brown_Hair'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
from deepface import DeepFace

import imageio.core.util
def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch4/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0882308
# /content/new06/batch4/a.pngb'Heavy_Makeup'.png5.png
# verified: /content/new06/batch4/a.pngb'Heavy_Makeup'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.4650648
# /content/new06/batch4/a.pngb'Goatee'.png5.png
# verified: /content/new06/batch4/a.pngb'Goatee'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.8917016
# /content/new06/batch4/a.pngb'Wearing_Earrings'.png6.png
# verified: /content/new06/batch4/a.pngb'Wearing_Earrings'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9393584
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch5/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.53500485
# /content/new06/batch5/a.pngb'Mustache'.png7.png
# verified: /content/new06/batch5/a.pngb'Mustache'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.53355014
# /content/new06/batch5/a.pngb'Narrow_Eyes'.png5.png
# verified: /content/new06/batch5/a.pngb'Narrow_Eyes'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.6182827
# /content/new06/batch5/a.pngb'Mustache'.png2.png
# verified: /content/new06/batch5/a.pngb'Mustache'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.5513481
# /content/new06/batch5/a.pngb'Mouth_Slightly_Open'.png4.png
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch6/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9393584
# /content/new06/batch6/a.pngb'Wearing_Hat'.png1.png
# verified: /content/new06/batch6/a.pngb'Wearing_Hat'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0901904
# /content/new06/batch6/a.pngb'Wearing_Necktie'.png3.png
# verified: /content/new06/batch6/a.pngb'Wearing_Necktie'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.97732973
# /content/new06/batch6/a.pngb'Young'.png7.png
# verified: /content/new06/batch6/a.pngb'Young'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9683132
# /content/new06/batch6/a.pngb'Young'.png6.png
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch7/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9393584
# /content/new06/batch7/a.pngb'Pointy_Nose'.png1.png
# verified: /content/new06/batch7/a.pngb'Pointy_Nose'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.153704
# /content/new06/batch7/a.pngb'Pale_Skin'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.441784
# /content/new06/batch7/a.pngb'Pointy_Nose'.png4.png
# verified: /content/new06/batch7/a.pngb'Pointy_Nose'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.051106
# /content/new06/batch7/a.pngb'Pale_Skin'.png4.png
# verified: /content/new06/batch7/a.pngb'Pale_Skin'.png4.png
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/new06/batch8/")  
srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/new06/batch1/000022.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      if result["distance"]<1.1:
         print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0965024
# /content/new06/batch8/a.pngb'Straight_Hair'.png5.png
# verified: /content/new06/batch8/a.pngb'Straight_Hair'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1060166
# /content/new06/batch8/a.pngb'Straight_Hair'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3234468
# /content/new06/batch8/a.pngb'Smiling'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9393584
# /content/new06/batch8/a.pngb'Rosy_Cheeks'.png1.png
# verified: /content/new06/batch8/a.pngb'Rosy_Cheeks'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# ...
