# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/person05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os 

g = os.walk(r"/content/person_new05/batch1/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.5391285
# /content/person_new05/batch1/a.pngb'Attractive'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4550242
# /content/person_new05/batch1/a.pngb'Arched_Eyebrows'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3829379
# /content/person_new05/batch1/a.pngb'5_o_Clock_Shadow'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.405078
# /content/person_new05/batch1/a.pngb'5_o_Clock_Shadow'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch2/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch2/a.pngb'Bangs'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2866833
# /content/person_new05/batch2/a.pngb'Bangs'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.36419
# /content/person_new05/batch2/a.pngb'Big_Nose'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2282057
# /content/person_new05/batch2/a.pngb'Bangs'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.354936
# /content/person_new05/batch2/a.pngb'Big_Nose'.png4.png
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch3/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.70794547
# /content/person_new05/batch3/a.pngb'Brown_Hair'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch3/a.pngb'Chubby'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch3/a.pngb'Bushy_Eyebrows'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch3/a.pngb'Eyeglasses'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2773042
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch4/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0440537
# /content/person_new05/batch4/a.pngb'Male'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.398785
# /content/person_new05/batch4/a.pngb'Male'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.7423926
# /content/person_new05/batch4/a.pngb'Heavy_Makeup'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3551376
# /content/person_new05/batch4/a.pngb'Goatee'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.37077
# /content/person_new05/batch4/a.pngb'High_Cheekbones'.png5.png
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch5/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3516859
# /content/person_new05/batch5/a.pngb'Narrow_Eyes'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3177477
# /content/person_new05/batch5/a.pngb'Oval_Face'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4063996
# /content/person_new05/batch5/a.pngb'No_Beard'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3708742
# /content/person_new05/batch5/a.pngb'Oval_Face'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0951654
# /content/person_new05/batch5/a.pngb'Mustache'.png8.png
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch6/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2809647
# /content/person_new05/batch6/a.pngb'Rosy_Cheeks'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3992506
# /content/person_new05/batch6/a.pngb'Sideburns'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch6/a.pngb'Pointy_Nose'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.407025
# /content/person_new05/batch6/a.pngb'Pointy_Nose'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3495499
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch7/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.77013934
# /content/person_new05/batch7/a.pngb'Wearing_Lipstick'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3470685
# /content/person_new05/batch7/a.pngb'Wavy_Hair'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4007989
# /content/person_new05/batch7/a.pngb'Wavy_Hair'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.87292856
# /content/person_new05/batch7/a.pngb'Wearing_Hat'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import os 

g = os.walk(r"/content/person_new05/batch8/")  
#srcPath='/content/verified/'

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/person_new05/batch1/000034.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print(os.path.join(path, file_name))
  
      #if result["distance"]<1.1:
       #  print('verified:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4171419
# /content/person_new05/batch8/a.pngb'Wearing_Necktie'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2585733
# /content/person_new05/batch8/a.pngb'Young'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.7666245
# /content/person_new05/batch8/a.pngb'Wearing_Necklace'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4447223
# /content/person_new05/batch8/a.pngb'Wearing_Necktie'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.4350069
# ...
