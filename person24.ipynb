# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/person24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch01/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
      #if result["distance"]<1.1:
       # path = os.path.join(path+str(file_name))
        #with open(path, 'rb') as rstream:
         #   container = rstream.read()
           
          #  path2 = os.path.join(dstPath+'/'+str(file_name))
           # with open(path2, 'wb') as wstream:
            #  wstream.write(container)
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.39723
# location: /content/newperson24/batch01/a.pngb'Gray_Hair'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3847969
# location: /content/newperson24/batch01/a.pngb'Wavy_Hair'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3673564
# location: /content/newperson24/batch01/a.pngb'Narrow_Eyes'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9687198
# location: /content/newperson24/batch01/a.pngb'Blond_Hair'.png1.png
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch02/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1090089
# location: /content/newperson24/batch02/a.pngb'Mouth_Slightly_Open'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0017747
# location: /content/newperson24/batch02/a.pngb'5_o_Clock_Shadow'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0060871
# location: /content/newperson24/batch02/a.pngb'Big_Lips'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3227401
# location: /content/newperson24/batch02/a.pngb'Eyeglasses'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch03/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3704385
# location: /content/newperson24/batch03/a.pngb'Bags_Under_Eyes'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2947168
# location: /content/newperson24/batch03/a.pngb'Attractive'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9687198
# location: /content/newperson24/batch03/a.pngb'5_o_Clock_Shadow'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0267897
# location: /content/newperson24/batch03/a.pngb'Eyeglasses'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3850926
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch04/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9949461
# location: /content/newperson24/batch04/a.pngb'Big_Lips'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3245419
# location: /content/newperson24/batch04/a.pngb'Wearing_Necklace'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9687198
# location: /content/newperson24/batch04/a.pngb'Rosy_Cheeks'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2093722
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch05/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.182761
# location: /content/newperson24/batch05/a.pngb'Pale_Skin'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0361682
# location: /content/newperson24/batch05/a.pngb'Rosy_Cheeks'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3166565
# location: /content/newperson24/batch05/a.pngb'Bags_Under_Eyes'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1298442
# location: /content/newperson24/batch05/a.pngb'Brown_Hair'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch06/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2236252
# location: /content/newperson24/batch06/a.pngb'Arched_Eyebrows'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0218315
# location: /content/newperson24/batch06/a.pngb'Big_Lips'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0635407
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch07/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.371666
# location: /content/newperson24/batch07/a.pngb'Bags_Under_Eyes'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.9687198
# location: /content/newperson24/batch07/a.pngb'Attractive'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.2568668
# location: /content/newperson24/batch07/a.pngb'Mustache'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson24/batch08/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000010.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3490047
# location: /content/newperson24/batch08/a.pngb'Male'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1070797
# location: /content/newperson24/batch08/a.pngb'Goatee'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3108659
# location: /content/newperson24/batch08/a.pngb'Bangs'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.219093
# location: /content/newperson24/batch08/a.pngb'Blond_Hair'.png6.png
# ...
