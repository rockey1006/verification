# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/0202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/facenet_weights.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/root/.deepface/weights/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/LFW0118/batch014.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/')

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/batchwrong.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/')

# %%
import sys
import base64
import cv2
import time
from deepface import DeepFace
from deepface.commons import functions, realtime, distance as dst
from deepface.basemodels import VGGFace, OpenFace, Facenet, FbDeepFace, DeepID
import numpy as np
import imageio

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
facenet_model = Facenet.loadModel()

def load_img2(img, do_random_crop, do_random_flip, image_size, do_prewhiten=True):
	images = np.zeros((1, image_size, image_size, 3))
	# scale pixel values
	face_pixels = img.astype('float32')
	# standardize pixel values across channels (global)
	mean, std = face_pixels.mean(), face_pixels.std()
	face_pixels = (face_pixels - mean) / std
	# transform face into one sample
	images[:,:,:,:] = face_pixels
	return images

# %%
def verify_distance(img1, img2):   # assumes image is in 160x160 format
	img1 = load_img2(img1, False, False, 160)
	img2 = load_img2(img2, False, False, 160)
	img1_representation = facenet_model.predict(img1)[0,:]
	img2_representation = facenet_model.predict(img2)[0,:]
	#distance1 = dst.findCosineDistance(img1_representation, img2_representation)
	#distance2 = dst.findEuclideanDistance(img1_representation, img2_representation)
	distance3 = dst.findEuclideanDistance(dst.l2_normalize(img1_representation), dst.l2_normalize(img2_representation))
	#result = str(distance1) + ' ' + str(distance2) + ' ' + str(distance3)
	return distance3
from skimage import io

# %%
def facedetect_image(img_file):  # detects face and returns 160x160 image around face
  imagePath = img_file
  image = io.imread(imagePath)
  margin = 3  # 3 pixel extra around detected face
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  faces = faceCascade.detectMultiScale(
		gray,
		scaleFactor=1.3,
		minNeighbors=3,
		minSize=(30, 30)
	)
 
  for (x, y, w, h) in faces:
		#cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    roi_color = image[y-margin:y + h+margin, x-margin:x + w+margin]
    dsize=(160,160)
    global imface
    try:
      imface = cv2.resize(roi_color, dsize, interpolation = cv2.INTER_AREA)
    except:
      continue
    imface = cv2.resize(roi_color, dsize, interpolation = cv2.INTER_AREA)
    
		#print("[INFO] Object found. Saving locally.")
		#cv2.imwrite(str(w) + str(h) + '_faces.jpg', imface1)
    encoded_string = imface 
    break
  return imface

# %%
def main():
  import os 

  g = os.walk(r"/content/batch014/batch29/") 
  srcPath='/content/batch014_verified/Donald_Rumsfeld_0092_0'
  if not os.path.exists(srcPath):
        os.makedirs(srcPath)
  img1 = facedetect_image('/content/batchwrong/batch014/Donald_Rumsfeld_0092_0.png/')


  for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
        img2 = facedetect_image(os.path.join(path, file_name))
      except:
        continue
      img2 = facedetect_image(os.path.join(path, file_name))
     
      
      res = verify_distance(img1,img2)
      #print("euclidean_l2 distance: ",res)
      if res<1.2:
        print("euclidean_l2 distance: ",res)
        path1 = os.path.join(path,file_name)


        path2 = os.path.join(srcPath+'/'+str(res))
     
        with open(path1, 'rb') as rstream:
          container = rstream.read()
          with open(path2, 'wb') as wstream:
            wstream.write(container)

if __name__ == "__main__":
    sys.exit(int(main() or 0))
# Out:
# euclidean_l2 distance:  1.197758
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1385223
# euclidean_l2 distance:  1.0729727
# euclidean_l2 distance:  1.1868573
# euclidean_l2 distance:  1.1868573
# euclidean_l2 distance:  1.1538107
# euclidean_l2 distance:  1.1538107
# euclidean_l2 distance:  1.1538107
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1967064
# euclidean_l2 distance:  1.1592412
# euclidean_l2 distance:  1.1781716
# euclidean_l2 distance:  1.1428826
# euclidean_l2 distance:  1.1487616
# euclidean_l2 distance:  1.1534424
# euclidean_l2 distance:  1.1534424
# euclidean_l2 distance:  1.1638196
# euclidean_l2 distance:  1.199572
# euclidean_l2 distance:  1.0728548
# euclidean_l2 distance:  1.1038041
# euclidean_l2 distance:  1.1964741
# euclidean_l2 distance:  1.1844221
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1308573
# euclidean_l2 distance:  1.1419971
# euclidean_l2 distance:  1.1376005
# euclidean_l2 distance:  1.0226092
# euclidean_l2 distance:  1.1360931
# euclidean_l2 distance:  1.1360931
# euclidean_l2 distance:  1.1838163
# euclidean_l2 distance:  1.1838163
# euclidean_l2 distance:  1.1812254
# euclidean_l2 distance:  1.1522475
# euclidean_l2 distance:  1.1375155
# euclidean_l2 distance:  1.1975372
# euclidean_l2 distance:  1.1328179
# euclidean_l2 distance:  1.1328179
# euclidean_l2 distance:  1.1694638
# euclidean_l2 distance:  1.1893921
# euclidean_l2 distance:  1.1752979
# euclidean_l2 distance:  1.1086308
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.0897722
# euclidean_l2 distance:  1.1415075
# euclidean_l2 distance:  1.1004195
# euclidean_l2 distance:  1.131783
# euclidean_l2 distance:  1.131783
# euclidean_l2 distance:  1.1573082
# euclidean_l2 distance:  1.122598
# euclidean_l2 distance:  1.1797731
# euclidean_l2 distance:  1.1797731
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1682833
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.10951
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1871691
# euclidean_l2 distance:  1.1871691
# euclidean_l2 distance:  1.1639313
# euclidean_l2 distance:  1.1755244
# euclidean_l2 distance:  1.1342115
# euclidean_l2 distance:  1.1514544
# euclidean_l2 distance:  1.19538
# euclidean_l2 distance:  1.1169521
# euclidean_l2 distance:  1.1893177
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.163851
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1897703
# euclidean_l2 distance:  1.0679388
# euclidean_l2 distance:  1.1635766
# euclidean_l2 distance:  1.1635766
# euclidean_l2 distance:  1.192156
# euclidean_l2 distance:  1.1672351
# euclidean_l2 distance:  1.1696169
# euclidean_l2 distance:  1.1696169
# euclidean_l2 distance:  1.1696169
# euclidean_l2 distance:  1.1112242
# euclidean_l2 distance:  1.1282866
# euclidean_l2 distance:  1.1452508
# euclidean_l2 distance:  1.12663
# euclidean_l2 distance:  1.1524006
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712172
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1389599
# euclidean_l2 distance:  1.13094
# euclidean_l2 distance:  1.13094
# euclidean_l2 distance:  1.13094
# euclidean_l2 distance:  1.1415633
# euclidean_l2 distance:  1.1152292
# euclidean_l2 distance:  1.157912
# euclidean_l2 distance:  1.1799153
# euclidean_l2 distance:  1.1921345
# euclidean_l2 distance:  1.1921345
# euclidean_l2 distance:  1.130574
# euclidean_l2 distance:  1.130574
# euclidean_l2 distance:  1.1395943
# euclidean_l2 distance:  1.1809534
# euclidean_l2 distance:  1.1341327
# euclidean_l2 distance:  1.1811117
# euclidean_l2 distance:  1.1139466
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1477585
# euclidean_l2 distance:  1.1477585
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.0531523
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1685761
# euclidean_l2 distance:  1.1763852
# euclidean_l2 distance:  1.1276993
# euclidean_l2 distance:  1.1600834
# euclidean_l2 distance:  1.1600834
# euclidean_l2 distance:  1.1466181
# euclidean_l2 distance:  1.1748621
# euclidean_l2 distance:  1.1748621
# euclidean_l2 distance:  1.1523881
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1267654
# euclidean_l2 distance:  1.1261591
# euclidean_l2 distance:  1.1261591
# euclidean_l2 distance:  1.1122766
# euclidean_l2 distance:  1.1684042
# euclidean_l2 distance:  1.0981588
# euclidean_l2 distance:  1.1498444
# euclidean_l2 distance:  1.1498444
# euclidean_l2 distance:  1.1498444
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1418182
# euclidean_l2 distance:  1.0857164
# euclidean_l2 distance:  1.1774752
# euclidean_l2 distance:  1.1456556
# euclidean_l2 distance:  1.0788503
# euclidean_l2 distance:  1.0846877
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1780862
# euclidean_l2 distance:  1.1780862
# euclidean_l2 distance:  1.1707933
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1991489
# euclidean_l2 distance:  1.196062
# euclidean_l2 distance:  1.169541
# euclidean_l2 distance:  1.1618153
# euclidean_l2 distance:  1.1812027
# euclidean_l2 distance:  1.1553309
# euclidean_l2 distance:  1.1955605
# euclidean_l2 distance:  1.1491793
# euclidean_l2 distance:  1.1791677
# euclidean_l2 distance:  1.168395
# euclidean_l2 distance:  1.1330401
# euclidean_l2 distance:  1.1516944
# euclidean_l2 distance:  1.1516944
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1750649
# euclidean_l2 distance:  1.189591
# euclidean_l2 distance:  1.1312557
# euclidean_l2 distance:  1.1341255
# euclidean_l2 distance:  1.1755699
# euclidean_l2 distance:  1.1755699
# euclidean_l2 distance:  1.1386727
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.150183
# euclidean_l2 distance:  1.1612327
# euclidean_l2 distance:  1.1072602
# euclidean_l2 distance:  1.145131
# euclidean_l2 distance:  1.1263424
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1566381
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.0982782
# euclidean_l2 distance:  1.0982782
# euclidean_l2 distance:  1.0982782
# euclidean_l2 distance:  1.0734473
# euclidean_l2 distance:  1.1972513
# euclidean_l2 distance:  1.1751112
# euclidean_l2 distance:  1.1835184
# euclidean_l2 distance:  1.1835184
# euclidean_l2 distance:  1.1440072
# euclidean_l2 distance:  1.1440072
# euclidean_l2 distance:  1.1440072
# euclidean_l2 distance:  1.1440072
# euclidean_l2 distance:  1.1315902
# euclidean_l2 distance:  1.1315902
# euclidean_l2 distance:  1.1315902
# euclidean_l2 distance:  1.1706309
# euclidean_l2 distance:  1.1491396
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.151224
# euclidean_l2 distance:  1.128901
# euclidean_l2 distance:  1.1745027
# euclidean_l2 distance:  1.1747884
# euclidean_l2 distance:  1.1747884
# euclidean_l2 distance:  1.0974306
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1010424
# euclidean_l2 distance:  1.1290411
# euclidean_l2 distance:  1.149822
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1665021
# euclidean_l2 distance:  1.1948755
# euclidean_l2 distance:  1.191784
# euclidean_l2 distance:  1.1486052
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.169749
# euclidean_l2 distance:  1.1659254
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.0501091
# euclidean_l2 distance:  1.0501091
# euclidean_l2 distance:  1.0640295
# euclidean_l2 distance:  1.1930461
# euclidean_l2 distance:  1.174895
# euclidean_l2 distance:  1.174895
# euclidean_l2 distance:  1.174895
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1330405
# euclidean_l2 distance:  1.149385
# euclidean_l2 distance:  1.149385
# euclidean_l2 distance:  1.1885824
# euclidean_l2 distance:  1.1910077
# euclidean_l2 distance:  1.1910077
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1654536
# euclidean_l2 distance:  1.101439
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1993984
# euclidean_l2 distance:  1.1066214
# euclidean_l2 distance:  1.1066214
# euclidean_l2 distance:  1.1712092
# euclidean_l2 distance:  1.1545742
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
# !zip -r /content/drive/MyDrive/LFW_VERIFIED0128/batch014_verified.zip /content/batch014_verified
