# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/verification/blob/main/person34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch01/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0303922
# location: /content/newperson34/batch01/a.pngb'Gray_Hair'.png3.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.96744996
# location: /content/newperson34/batch01/a.pngb'Wavy_Hair'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1792817
# location: /content/newperson34/batch01/a.pngb'Narrow_Eyes'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0560296
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch02/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0060408
# location: /content/newperson34/batch02/a.pngb'Mouth_Slightly_Open'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0884397
# location: /content/newperson34/batch02/a.pngb'5_o_Clock_Shadow'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0276608
# location: /content/newperson34/batch02/a.pngb'Big_Lips'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1586134
# location: /content/newperson34/batch02/a.pngb'Narrow_Eyes'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1097717
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch03/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0953214
# location: /content/newperson34/batch03/a.pngb'Bags_Under_Eyes'.png9.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3477783
# location: /content/newperson34/batch03/a.pngb'Attractive'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0560296
# location: /content/newperson34/batch03/a.pngb'5_o_Clock_Shadow'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0509046
# location: /content/newperson34/batch03/a.pngb'Eyeglasses'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch04/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0348307
# location: /content/newperson34/batch04/a.pngb'Big_Lips'.png5.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.86885774
# location: /content/newperson34/batch04/a.pngb'Wearing_Necklace'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0560296
# location: /content/newperson34/batch04/a.pngb'Rosy_Cheeks'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch05/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.3431128
# location: /content/newperson34/batch05/a.pngb'Pale_Skin'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.87453717
# location: /content/newperson34/batch05/a.pngb'Rosy_Cheeks'.png2.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0960318
# location: /content/newperson34/batch05/a.pngb'Bags_Under_Eyes'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.83760405
# location: /content/newperson34/batch05/a.pngb'Brown_Hair'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch06/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.984354
# location: /content/newperson34/batch06/a.pngb'Arched_Eyebrows'.png6.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  0.96997285
# location: /content/newperson34/batch06/a.pngb'Big_Lips'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.247576
# location: /content/newperson34/batch06/a.pngb'Rosy_Cheeks'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch07/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1037173
# location: /content/newperson34/batch07/a.pngb'Bags_Under_Eyes'.png8.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0560296
# location: /content/newperson34/batch07/a.pngb'Attractive'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0226246
# location: /content/newperson34/batch07/a.pngb'Blurry'.png3.png
# ...

# %%
import imageio
import imageio.core.util
from deepface import DeepFace

def silence_imageio_warning(*args, **kwargs):
    pass
imageio.core.util._precision_warn = silence_imageio_warning
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
import os 

g = os.walk(r"/content/newperson34/batch08/")  
dstPath='/content/verified13/'
if not os.path.exists(dstPath):
        os.makedirs(dstPath)

for path,dir_list,file_list in g:  
    for file_name in file_list:  
      try:
          result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
      except:
        continue
      result  = DeepFace.verify('/content/personD/needed1118_f/000032.png', os.path.join(path, file_name),model_name="Facenet",distance_metric='euclidean_l2')
       
      print("euclidean_l2 distance: ",result["distance"])
      print('location:',os.path.join(path, file_name))
# Out:
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1648573
# location: /content/newperson34/batch08/a.pngb'Narrow_Eyes'.png7.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.1065049
# location: /content/newperson34/batch08/a.pngb'Goatee'.png4.png
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# Using Facenet model backend euclidean_l2 distance.
# euclidean_l2 distance:  1.0560294
# location: /content/newperson34/batch08/a.pngb'Wearing_Earrings'.png1.png
# Using Facenet model backend euclidean_l2 distance.
# ...
